# %%
import pandas as pd
import plotly.express as px

# %%
data = [
    {"nazwa": "DOLNOŚLĄSKIE", "2019": 0.4385, "2020": 0.4602, "2021": 0.5307, "2022": 0.5672, "2023": 0.4789, "2024": 0.4918},
    {"nazwa": "KUJAWSKO-POMORSKIE", "2019": 0.1426, "2020": 0.1676, "2021": 0.1863, "2022": 0.2000, "2023": 0.1782, "2024": 0.1795},
    {"nazwa": "LUBELSKIE", "2019": 0.1329, "2020": 0.1348, "2021": 0.1376, "2022": 0.1390, "2023": 0.1258, "2024": 0.1363},
    {"nazwa": "LUBUSKIE", "2019": 0.2191, "2020": 0.2148, "2021": 0.2721, "2022": 0.2882, "2023": 0.2762, "2024": 0.2599},
    {"nazwa": "ŁÓDZKIE", "2019": 0.2887, "2020": 0.3016, "2021": 0.3269, "2022": 0.3226, "2023": 0.3558, "2024": 0.3189},
    {"nazwa": "MAŁOPOLSKIE", "2019": 0.3641, "2020": 0.4025, "2021": 0.4098, "2022": 0.4233, "2023": 0.3518, "2024": 0.3441},
    {"nazwa": "MAZOWIECKIE", "2019": 0.4734, "2020": 0.4643, "2021": 0.5162, "2022": 0.5340, "2023": 0.5279, "2024": 0.5331},
    {"nazwa": "OPOLSKIE", "2019": 0.2942, "2020": 0.2520, "2021": 0.2647, "2022": 0.2846, "2023": 0.2653, "2024": 0.2720},
    {"nazwa": "PODKARPACKIE", "2019": 0.1588, "2020": 0.1493, "2021": 0.1066, "2022": 0.1465, "2023": 0.1433, "2024": 0.1520},
    {"nazwa": "PODLASKIE", "2019": 0.1733, "2020": 0.1607, "2021": 0.1551, "2022": 0.1668, "2023": 0.1451, "2024": 0.1834},
    {"nazwa": "POMORSKIE", "2019": 0.3429, "2020": 0.3345, "2021": 0.3540, "2022": 0.3293, "2023": 0.3042, "2024": 0.3004},
    {"nazwa": "ŚLĄSKIE", "2019": 0.4389, "2020": 0.4589, "2021": 0.4228, "2022": 0.4517, "2023": 0.3968, "2024": 0.3971},
    {"nazwa": "ŚWIĘTOKRZYSKIE", "2019": 0.1208, "2020": 0.1264, "2021": 0.1185, "2022": 0.1436, "2023": 0.1358, "2024": 0.1086},
    {"nazwa": "WARMIŃSKO-MAZURSKIE", "2019": 0.0098, "2020": 0.0076, "2021": 0.0681, "2022": 0.0359, "2023": 0.0427, "2024": 0.0351},
    {"nazwa": "WIELKOPOLSKIE", "2019": 0.3010, "2020": 0.3350, "2021": 0.3921, "2022": 0.4274, "2023": 0.3623, "2024": 0.3785},
    {"nazwa": "ZACHODNIOPOMORSKIE", "2019": 0.2131, "2020": 0.3078, "2021": 0.2774, "2022": 0.2977, "2023": 0.1921, "2024": 0.2046}
]

df = pd.DataFrame(data)

# %%
name_col = df.columns[0]

df_long = df.melt(id_vars=name_col, var_name="rok", value_name="mrg")
df_long["rok"] = df_long["rok"].astype(str)

years = sorted(df_long["rok"].unique())
n = len(years)

fig = px.bar(
    df_long,
    x="rok",
    y="mrg",
    color=name_col,
    barmode="group",
    title="Wartości MRG"
)

fig.update_xaxes(categoryorder="array", categoryarray=years)
fig.update_layout(xaxis_title="Rok", yaxis_title="")

for i in range(n):
    if i % 2 == 0:
        x0 = i / n
        x1 = (i + 1) / n
        fig.add_shape(
            type="rect",
            xref="paper",
            yref="paper",
            x0=x0,
            x1=x1,
            y0=0,
            y1=1,
            fillcolor="rgba(0,0,0,0.09)",
            line_width=0,
            layer="below"
        )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a7fd8946-33d2-4cb5-981c-79cb00b5dc61" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a7fd8946-33d2-4cb5-981c-79cb00b5dc61")) {                    Plotly.newPlot(                        "a7fd8946-33d2-4cb5-981c-79cb00b5dc61",                        [{"alignmentgroup":"True","hovertemplate":"nazwa=DOLNOŚLĄSKIE\u003cbr\u003erok=%{x}\u003cbr\u003emrg=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"DOLNOŚLĄSKIE","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"DOLNOŚLĄSKIE","offsetgroup":"DOLNOŚLĄSKIE","orientation":"v","showlegend":true,"textposition":"auto","x":["2019","2020","2021","2022","2023","2024"],"xaxis":"x","y":[0.4385,0.4602,0.5307,0.5672,0.4789,0.4918],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nazwa=KUJAWSKO-POMORSKIE\u003cbr\u003erok=%{x}\u003cbr\u003emrg=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"KUJAWSKO-POMORSKIE","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"KUJAWSKO-POMORSKIE","offsetgroup":"KUJAWSKO-POMORSKIE","orientation":"v","showlegend":true,"textposition":"auto","x":["2019","2020","2021","2022","2023","2024"],"xaxis":"x","y":[0.1426,0.1676,0.1863,0.2,0.1782,0.1795],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nazwa=LUBELSKIE\u003cbr\u003erok=%{x}\u003cbr\u003emrg=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"LUBELSKIE","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"LUBELSKIE","offsetgroup":"LUBELSKIE","orientation":"v","showlegend":true,"textposition":"auto","x":["2019","2020","2021","2022","2023","2024"],"xaxis":"x","y":[0.1329,0.1348,0.1376,0.139,0.1258,0.1363],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nazwa=LUBUSKIE\u003cbr\u003erok=%{x}\u003cbr\u003emrg=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"LUBUSKIE","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"LUBUSKIE","offsetgroup":"LUBUSKIE","orientation":"v","showlegend":true,"textposition":"auto","x":["2019","2020","2021","2022","2023","2024"],"xaxis":"x","y":[0.2191,0.2148,0.2721,0.2882,0.2762,0.2599],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nazwa=ŁÓDZKIE\u003cbr\u003erok=%{x}\u003cbr\u003emrg=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ŁÓDZKIE","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"ŁÓDZKIE","offsetgroup":"ŁÓDZKIE","orientation":"v","showlegend":true,"textposition":"auto","x":["2019","2020","2021","2022","2023","2024"],"xaxis":"x","y":[0.2887,0.3016,0.3269,0.3226,0.3558,0.3189],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nazwa=MAŁOPOLSKIE\u003cbr\u003erok=%{x}\u003cbr\u003emrg=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"MAŁOPOLSKIE","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"MAŁOPOLSKIE","offsetgroup":"MAŁOPOLSKIE","orientation":"v","showlegend":true,"textposition":"auto","x":["2019","2020","2021","2022","2023","2024"],"xaxis":"x","y":[0.3641,0.4025,0.4098,0.4233,0.3518,0.3441],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nazwa=MAZOWIECKIE\u003cbr\u003erok=%{x}\u003cbr\u003emrg=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"MAZOWIECKIE","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"MAZOWIECKIE","offsetgroup":"MAZOWIECKIE","orientation":"v","showlegend":true,"textposition":"auto","x":["2019","2020","2021","2022","2023","2024"],"xaxis":"x","y":[0.4734,0.4643,0.5162,0.534,0.5279,0.5331],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nazwa=OPOLSKIE\u003cbr\u003erok=%{x}\u003cbr\u003emrg=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"OPOLSKIE","marker":{"color ...

# %%
output_path = "mrg_wykres.html"
fig.write_html(output_path, include_plotlyjs=True)
